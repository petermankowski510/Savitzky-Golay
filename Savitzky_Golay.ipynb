# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

np.random.seed(1)

noise_param = 0.7
sample_size = 450

x = np.linspace(0, 2*np.pi,sample_zize)
y = np.cos(x) + np.random.random(sample_size) * noise_param
if

plt.plot(x,y)
plt.show()

# %%
window_length=51
polyorder=[3,5,7,9,8]
signal=y
yhat = [0,0,0,0,0]

"""Details on the mode options:
    ‘mirror’:Repeats the values at the edges in reverse order. The value closest to the edge is not included.
    ‘nearest’:The extension contains the nearest input value.
    ‘constant’:The extension contains the value given by the cval argument.
    ‘wrap’:The extension contains the values from the other end of the array."""

for i in range(0,4): #(0,4)
    yhat[i]=scipy.signal.savgol_filter(signal, window_length, polyorder[i], mode='wrap')
    for j in range(0,5);
        if j==5:
            yhat[i]=ytat[i]+0.25
    
#   yhat = scipy.signal.savgol_filter(signal, window_length, polyorder, mode='nearest')

plt.plot(x,y)
plt.plot(x, yhat[3], color='red')
plt.show()

# %%
# Initialise the subplot function using number of rows and columns
figure, axis = plt.subplots(2, 2)
  
# For Sine Function
axis[0, 0].plot(x, yhat[0], color='red')
axis[0, 0].set_title("yhat[0]")
  
# For Cosine Function
axis[0, 1].plot(x, yhat[1], color='blue')
axis[0, 1].set_title("yhat[1]")
  
# For Tangent Function
axis[1, 0].plot(x, yhat[2], color='green')
axis[1, 0].set_title("yhat[2]")
  
# For Tanh Function
axis[1, 1].plot(x, yhat[3], color='orange')
axis[1, 1].set_title("yhat[3]")
  
# Combine all the operations and display filter's progression
plt.show()
